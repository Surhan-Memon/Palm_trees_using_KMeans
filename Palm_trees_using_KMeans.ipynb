# %% [markdown]
# <a href="https://colab.research.google.com/github/Surhan-Memon/Palm_trees_using_KMeans/blob/main/Palm_trees_using_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_as_array = mpimg.imread('/content/ck4cj8prb3n5l0706y00lz4ha.jpeg')

# %%
image_as_array.shape
# Out:
# (2160, 4096, 3)

# %%
plt.imshow(image_as_array)

# %%
(h,w,c) = image_as_array.shape

# %%
c
# Out:
# 3

# %%
image_as_array2d = image_as_array.reshape(h*w,c)

# %%
len(image_as_array.shape)
# Out:
# 3

# %%
len(image_as_array2d.shape)
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
2160*4096
# Out:
# 8847360

# %%
labels
# Out:
# array([0, 3, 0, ..., 4, 4, 4], dtype=int32)

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[ 63,  62,  59],
#        [198, 196, 189],
#        [167, 163, 154],
#        [ 97,  96,  92],
#        [ 30,  32,  27],
#        [127, 129, 127]])

# %%
rgb_codes[labels]
# Out:
# array([[63, 62, 59],
#        [97, 96, 92],
#        [63, 62, 59],
#        ...,
#        [30, 32, 27],
#        [30, 32, 27],
#        [30, 32, 27]])

# %%
quantized_image = np.reshape(rgb_codes[labels],(h,w,c))

# %%
plt.imshow(quantized_image)
